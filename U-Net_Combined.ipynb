# %%
# import system libs
import os
import time
import random
import pathlib
import itertools
from glob import glob
from tqdm import tqdm_notebook, tnrange

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.color import rgb2gray
from skimage.morphology import label
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from skimage.io import imread, imshow, concatenate_images

# import Deep learning Libraries
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.layers import Input, Activation,  Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
def create_df(data_dir):
    images_paths = []
    masks_paths = glob(f'{data_dir}/*/*_mask*')

    for i in masks_paths:
        images_paths.append(i.replace('_mask', ''))

    df = pd.DataFrame(data= {'images_paths': images_paths, 'masks_paths': masks_paths})

    return df

def split_df(df):
    # create train_df
    train_df, dummy_df = train_test_split(df, train_size= 0.8)

    # create valid_df and test_df
    valid_df, test_df = train_test_split(dummy_df, train_size= 0.5)

    return train_df, valid_df, test_df

# %%
def create_gens(df, aug_dict):
    img_size = (128, 128)
    batch_size = 40


    img_gen = ImageDataGenerator(**aug_dict)
    msk_gen = ImageDataGenerator(**aug_dict)

    # Create general generator
    image_gen = img_gen.flow_from_dataframe(df, x_col='images_paths', class_mode=None, color_mode='rgb', target_size=img_size,
                                            batch_size=batch_size, save_to_dir=None, save_prefix='image', seed=1)

    mask_gen = msk_gen.flow_from_dataframe(df, x_col='masks_paths', class_mode=None, color_mode='grayscale', target_size=img_size,
                                            batch_size=batch_size, save_to_dir=None, save_prefix= 'mask', seed=1)

    gen = zip(image_gen, mask_gen)

    for (img, msk) in gen:
        img = img / 255
        msk = msk / 255
        msk[msk > 0.5] = 1
        msk[msk <= 0.5] = 0

        yield (img, msk)

# %%
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, Conv2DTranspose, MaxPooling2D, BatchNormalization, Activation, concatenate
from tensorflow.keras.models import Model

def combined_conv_block(x, filters):
    # Depth-wise separable convolution block
    x = SeparableConv2D(filters, (3, 3), padding='same')(x)
    x = Activation('relu')(x)
    x = SeparableConv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    # Low-rank factorization of a 3x3 convolution:
    # Factorize a 3x3 kernel into a 3x1 followed by a 1x3 convolution.
    x = Conv2D(filters, (3, 1), padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, (1, 3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)
    return x

def unet(input_size=(128, 128, 3)):
    inputs = Input(input_size)

    # Encoder (Downsampling path)
    c1 = combined_conv_block(inputs, 16)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = combined_conv_block(p1, 32)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = combined_conv_block(p2, 48)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = combined_conv_block(p3, 64)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = combined_conv_block(p4, 64)

    # Decoder (Upsampling path)
    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4], axis=3)
    c6 = combined_conv_block(u6, 64)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3], axis=3)
    c7 = combined_conv_block(u7, 48)

    u8 = Conv2DTranspose(48, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2], axis=3)
    c8 = combined_conv_block(u8, 32)

    u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = combined_conv_block(u9, 16)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs, outputs)
    return model

# %%
# function to create dice coefficient
def dice_coef(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

# function to create dice loss
def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)

# function to create iou coefficient
def iou_coef(y_true, y_pred, smooth=100):
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    return iou

# %%
def show_images(images, masks):
    plt.figure(figsize=(12, 12))
    for i in range(25):
        plt.subplot(5, 5, i+1)
        img_path = images[i]
        mask_path = masks[i]
        # read image and convert it to RGB scale
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        # read mask
        mask = cv2.imread(mask_path)
        # sho image and mask
        plt.imshow(image)
        plt.imshow(mask, alpha=0.4)

        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables
    tr_acc = hist.history['accuracy']
    tr_iou = hist.history['iou_coef']
    tr_dice = hist.history['dice_coef']
    tr_loss = hist.history['loss']

    val_acc = hist.history['val_accuracy']
    val_iou = hist.history['val_iou_coef']
    val_dice = hist.history['val_dice_coef']
    val_loss = hist.history['val_loss']

    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    index_iou = np.argmax(iou_coef)
    iou_highest = val_iou[index_iou]
    index_dice = np.argmax(dice_coef)
    dice_highest = val_dice[index_dice]
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]

    Epochs = [i+1 for i in range(len(tr_acc))]

    acc_label = f'best epoch= {str(index_acc + 1)}'
    iou_label = f'best epoch= {str(index_iou + 1)}'
    dice_label = f'best epoch= {str(index_dice + 1)}'
    loss_label = f'best epoch= {str(index_loss + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 20))
    plt.style.use('fivethirtyeight')

    # Training Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training IoU
    plt.subplot(2, 2, 2)
    plt.plot(Epochs, tr_iou, 'r', label= 'Training IoU')
    plt.plot(Epochs, val_iou, 'g', label= 'Validation IoU')
    plt.scatter(index_iou + 1 , iou_highest, s= 150, c= 'blue', label= iou_label)
    plt.title('Training and Validation IoU Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('IoU')
    plt.legend()

    # Training Dice
    plt.subplot(2, 2, 3)
    plt.plot(Epochs, tr_dice, 'r', label= 'Training Dice')
    plt.plot(Epochs, val_dice, 'g', label= 'Validation Dice')
    plt.scatter(index_dice + 1 , dice_highest, s= 150, c= 'blue', label= dice_label)
    plt.title('Training and Validation Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice')
    plt.legend()

    # Training Loss
    plt.subplot(2, 2, 4)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Update the data directory to point to your dataset on Google Drive
data_dir = '/content/drive/MyDrive/lgg-mri-segmentation/kaggle_3m'

df = create_df(data_dir)
train_df, valid_df, test_df = split_df(df)


tr_aug_dict = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')


train_gen = create_gens(train_df, aug_dict=tr_aug_dict)
valid_gen = create_gens(valid_df, aug_dict={})
test_gen = create_gens(test_df, aug_dict={})

show_images(list(train_df['images_paths']), list(train_df['masks_paths']))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = unet()
model.compile(Adamax(learning_rate= 0.001), loss= dice_loss, metrics= ['accuracy', iou_coef, dice_coef])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 128, 128, 16)   │             91 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 128, 128, 16)   │              0 │ separable_conv2d_1[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 16)   │            416 │ activation[0][0]       │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128, 128, 16)   │             64 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 128, 128, 16)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 16)   │            784 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 128, 128, 16)   │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 16)   │            784 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 16)   │             64 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 16)     │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 64, 64, 32)     │            688 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64, 64, 32)     │              0 │ separable_conv2d_3[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 32)     │          1,344 │ activation_4[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 64, 64, 32)     │            128 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 64, 64, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 32)     │          3,104 │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 64, 64, 32)     │              0 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 32)     │          3,104 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 64, 64, 32)     │            128 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 64, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 32)     │              0 │ activation_7[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 32, 32, 48)     │          1,872 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 32, 32, 48)     │              0 │ separable_conv2d_5[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 32, 32, 48)     │          2,784 │ activation_8[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 32, 32, 48)     │            192 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 48)     │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 48)     │          6,960 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 32, 32, 48)     │              0 │ conv2d_4[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 48)     │          6,960 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 32, 32, 48)     │            192 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 32, 32, 48)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 48)     │              0 │ activation_11[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 16, 16, 64)     │          3,568 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 16, 16, 64)     │              0 │ separable_conv2d_7[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 16, 16, 64)     │          4,736 │ activation_12[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 16, 16, 64)     │            256 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 16, 16, 64)     │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 64)     │         12,352 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 16, 16, 64)     │              0 │ conv2d_6[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 64)     │         12,352 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 16, 16, 64)     │            256 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 16, 16, 64)     │              0 │ batch_normalization_7… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 8, 8, 64)       │              0 │ activation_15[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 8, 8, 64)       │          4,736 │ max_pooling2d_3[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 8, 8, 64)       │              0 │ separable_conv2d_9[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_10       │ (None, 8, 8, 64)       │          4,736 │ activation_16[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 8, 8, 64)       │            256 │ separable_conv2d_10[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 8, 8, 64)       │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 8, 8, 64)       │         12,352 │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 8, 8, 64)       │              0 │ conv2d_8[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 8, 8, 64)       │         12,352 │ activation_18[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 8, 8, 64)       │            256 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 8, 8, 64)       │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 64)     │         16,448 │ activation_19[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 128)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_11       │ (None, 16, 16, 64)     │          9,408 │ concatenate[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 16, 16, 64)     │              0 │ separable_conv2d_11[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_12       │ (None, 16, 16, 64)     │          4,736 │ activation_20[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 64)     │            256 │ separable_conv2d_12[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 16, 16, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 64)     │         12,352 │ activation_21[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 16, 16, 64)     │              0 │ conv2d_10[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 64)     │         12,352 │ activation_22[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 64)     │            256 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 16, 16, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 64)     │         16,448 │ activation_23[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 112)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_13       │ (None, 32, 32, 48)     │          6,432 │ concatenate_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 32, 32, 48)     │              0 │ separable_conv2d_13[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_14       │ (None, 32, 32, 48)     │          2,784 │ activation_24[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 48)     │            192 │ separable_conv2d_14[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 32, 32, 48)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 48)     │          6,960 │ activation_25[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_26             │ (None, 32, 32, 48)     │              0 │ conv2d_12[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 48)     │          6,960 │ activation_26[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 48)     │            192 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_27             │ (None, 32, 32, 48)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 48)     │          9,264 │ activation_27[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 80)     │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_15       │ (None, 64, 64, 32)     │          3,312 │ concatenate_2[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_28             │ (None, 64, 64, 32)     │              0 │ separable_conv2d_15[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_16       │ (None, 64, 64, 32)     │          1,344 │ activation_28[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 64, 64, 32)     │            128 │ separable_conv2d_16[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_29             │ (None, 64, 64, 32)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 64, 64, 32)     │          3,104 │ activation_29[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_30             │ (None, 64, 64, 32)     │              0 │ conv2d_14[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 64, 32)     │          3,104 │ activation_30[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 64, 32)     │            128 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_31             │ (None, 64, 64, 32)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 32)   │          4,128 │ activation_31[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 48)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_17       │ (None, 128, 128, 16)   │          1,216 │ concatenate_3[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_32             │ (None, 128, 128, 16)   │              0 │ separable_conv2d_17[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_18       │ (None, 128, 128, 16)   │            416 │ activation_32[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 128, 128, 16)   │             64 │ separable_conv2d_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 16)   │            784 │ activation_33[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 128, 128, 16)   │              0 │ conv2d_16[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 128, 128, 16)   │            784 │ activation_34[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 128, 128, 16)   │             64 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 128, 128, 16)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 128, 128, 1)    │             17 │ activation_35[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 221,500 (865.23 KB)
#  Trainable params: 219,964 (859.23 KB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
import math
callbacks = [ModelCheckpoint('/content/drive/MyDrive/unet_final_combination.keras', verbose=1, save_best_only=True)]
epochs = 120
batch_size = 40

history = model.fit(train_gen,steps_per_epoch=math.ceil(len(train_df) / batch_size),epochs=epochs,verbose=1,callbacks=callbacks,validation_data=valid_gen,validation_steps=math.ceil(len(valid_df) / batch_size))
# Out:
# Found 3143 validated image filenames.
# Found 3143 validated image filenames.
# Epoch 1/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 55s/step - accuracy: 0.5777 - dice_coef: 0.0346 - iou_coef: 0.0178 - loss: -0.0346 Found 393 validated image filenames.
# Found 393 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.02288, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4911s 62s/step - accuracy: 0.5799 - dice_coef: 0.0347 - iou_coef: 0.0178 - loss: -0.0347 - val_accuracy: 0.9884 - val_dice_coef: 0.0228 - val_iou_coef: 0.0117 - val_loss: -0.0229
# Epoch 2/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.9031 - dice_coef: 0.0538 - iou_coef: 0.0280 - loss: -0.0539
# Epoch 2: val_loss did not improve from -0.02288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 550ms/step - accuracy: 0.9034 - dice_coef: 0.0539 - iou_coef: 0.0280 - loss: -0.0539 - val_accuracy: 0.9896 - val_dice_coef: 0.0204 - val_iou_coef: 0.0105 - val_loss: -0.0206
# Epoch 3/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9507 - dice_coef: 0.0763 - iou_coef: 0.0402 - loss: -0.0763
# Epoch 3: val_loss did not improve from -0.02288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9508 - dice_coef: 0.0764 - iou_coef: 0.0402 - loss: -0.0764 - val_accuracy: 0.9893 - val_dice_coef: 0.0211 - val_iou_coef: 0.0109 - val_loss: -0.0212
# Epoch 4/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.9764 - dice_coef: 0.1100 - iou_coef: 0.0589 - loss: -0.1100
# Epoch 4: val_loss did not improve from -0.02288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 532ms/step - accuracy: 0.9764 - dice_coef: 0.1101 - iou_coef: 0.0589 - loss: -0.1101 - val_accuracy: 0.9891 - val_dice_coef: 0.0215 - val_iou_coef: 0.0112 - val_loss: -0.0215
# Epoch 5/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9830 - dice_coef: 0.1290 - iou_coef: 0.0704 - loss: -0.1289
# Epoch 5: val_loss did not improve from -0.02288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9831 - dice_coef: 0.1293 - iou_coef: 0.0707 - loss: -0.1293 - val_accuracy: 0.9888 - val_dice_coef: 0.0218 - val_iou_coef: 0.0116 - val_loss: -0.0217
# Epoch 6/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9891 - dice_coef: 0.2141 - iou_coef: 0.1220 - loss: -0.2141
# Epoch 6: val_loss did not improve from -0.02288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 509ms/step - accuracy: 0.9891 - dice_coef: 0.2143 - iou_coef: 0.1221 - loss: -0.2143 - val_accuracy: 0.9890 - val_dice_coef: 0.0207 - val_iou_coef: 0.0115 - val_loss: -0.0206
# Epoch 7/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9900 - dice_coef: 0.2859 - iou_coef: 0.1719 - loss: -0.2859
# Epoch 7: val_loss improved from -0.02288 to -0.06532, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 546ms/step - accuracy: 0.9900 - dice_coef: 0.2866 - iou_coef: 0.1723 - loss: -0.2865 - val_accuracy: 0.9898 - val_dice_coef: 0.0660 - val_iou_coef: 0.0362 - val_loss: -0.0653
# Epoch 8/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9902 - dice_coef: 0.3685 - iou_coef: 0.2367 - loss: -0.3685
# Epoch 8: val_loss improved from -0.06532 to -0.32906, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 544ms/step - accuracy: 0.9902 - dice_coef: 0.3696 - iou_coef: 0.2376 - loss: -0.3696 - val_accuracy: 0.9920 - val_dice_coef: 0.3288 - val_iou_coef: 0.2020 - val_loss: -0.3291
# Epoch 9/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9916 - dice_coef: 0.4971 - iou_coef: 0.3455 - loss: -0.4971
# Epoch 9: val_loss improved from -0.32906 to -0.51129, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9916 - dice_coef: 0.4980 - iou_coef: 0.3463 - loss: -0.4980 - val_accuracy: 0.9933 - val_dice_coef: 0.5125 - val_iou_coef: 0.3519 - val_loss: -0.5113
# Epoch 10/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9954 - dice_coef: 0.6646 - iou_coef: 0.5037 - loss: -0.6647
# Epoch 10: val_loss improved from -0.51129 to -0.66888, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 36s 466ms/step - accuracy: 0.9955 - dice_coef: 0.6648 - iou_coef: 0.5039 - loss: -0.6648 - val_accuracy: 0.9929 - val_dice_coef: 0.6696 - val_iou_coef: 0.5063 - val_loss: -0.6689
# Epoch 11/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9925 - dice_coef: 0.6120 - iou_coef: 0.4666 - loss: -0.6120
# Epoch 11: val_loss improved from -0.66888 to -0.72478, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 553ms/step - accuracy: 0.9925 - dice_coef: 0.6131 - iou_coef: 0.4677 - loss: -0.6130 - val_accuracy: 0.9958 - val_dice_coef: 0.7238 - val_iou_coef: 0.5748 - val_loss: -0.7248
# Epoch 12/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9938 - dice_coef: 0.6589 - iou_coef: 0.5162 - loss: -0.6589
# Epoch 12: val_loss did not improve from -0.72478
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 530ms/step - accuracy: 0.9939 - dice_coef: 0.6597 - iou_coef: 0.5171 - loss: -0.6597 - val_accuracy: 0.9950 - val_dice_coef: 0.6857 - val_iou_coef: 0.5276 - val_loss: -0.6846
# Epoch 13/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9933 - dice_coef: 0.6736 - iou_coef: 0.5352 - loss: -0.6736
# Epoch 13: val_loss improved from -0.72478 to -0.75796, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9934 - dice_coef: 0.6745 - iou_coef: 0.5360 - loss: -0.6745 - val_accuracy: 0.9950 - val_dice_coef: 0.7591 - val_iou_coef: 0.6163 - val_loss: -0.7580
# Epoch 14/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9960 - dice_coef: 0.7847 - iou_coef: 0.6503 - loss: -0.7847
# Epoch 14: val_loss did not improve from -0.75796
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 359ms/step - accuracy: 0.9960 - dice_coef: 0.7847 - iou_coef: 0.6502 - loss: -0.7847 - val_accuracy: 0.9945 - val_dice_coef: 0.6895 - val_iou_coef: 0.5332 - val_loss: -0.6889
# Epoch 15/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9942 - dice_coef: 0.6983 - iou_coef: 0.5638 - loss: -0.6983
# Epoch 15: val_loss improved from -0.75796 to -0.78688, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 553ms/step - accuracy: 0.9942 - dice_coef: 0.6993 - iou_coef: 0.5648 - loss: -0.6992 - val_accuracy: 0.9957 - val_dice_coef: 0.7869 - val_iou_coef: 0.6511 - val_loss: -0.7869
# Epoch 16/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9944 - dice_coef: 0.7141 - iou_coef: 0.5853 - loss: -0.7141
# Epoch 16: val_loss improved from -0.78688 to -0.80288, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9944 - dice_coef: 0.7150 - iou_coef: 0.5862 - loss: -0.7150 - val_accuracy: 0.9960 - val_dice_coef: 0.8028 - val_iou_coef: 0.6737 - val_loss: -0.8029
# Epoch 17/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9967 - dice_coef: 0.8245 - iou_coef: 0.7045 - loss: -0.8245
# Epoch 17: val_loss did not improve from -0.80288
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - accuracy: 0.9967 - dice_coef: 0.8245 - iou_coef: 0.7045 - loss: -0.8245 - val_accuracy: 0.9961 - val_dice_coef: 0.7922 - val_iou_coef: 0.6595 - val_loss: -0.7911
# Epoch 18/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9941 - dice_coef: 0.7160 - iou_coef: 0.5937 - loss: -0.7160
# Epoch 18: val_loss improved from -0.80288 to -0.81924, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 545ms/step - accuracy: 0.9941 - dice_coef: 0.7170 - iou_coef: 0.5948 - loss: -0.7170 - val_accuracy: 0.9964 - val_dice_coef: 0.8199 - val_iou_coef: 0.6978 - val_loss: -0.8192
# Epoch 19/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9941 - dice_coef: 0.6937 - iou_coef: 0.5717 - loss: -0.6937
# Epoch 19: val_loss did not improve from -0.81924
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 527ms/step - accuracy: 0.9942 - dice_coef: 0.6949 - iou_coef: 0.5729 - loss: -0.6949 - val_accuracy: 0.9961 - val_dice_coef: 0.8066 - val_iou_coef: 0.6789 - val_loss: -0.8058
# Epoch 20/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9944 - dice_coef: 0.7142 - iou_coef: 0.5924 - loss: -0.7142
# Epoch 20: val_loss improved from -0.81924 to -0.82637, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 553ms/step - accuracy: 0.9944 - dice_coef: 0.7152 - iou_coef: 0.5935 - loss: -0.7153 - val_accuracy: 0.9963 - val_dice_coef: 0.8267 - val_iou_coef: 0.7076 - val_loss: -0.8264
# Epoch 21/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9949 - dice_coef: 0.7337 - iou_coef: 0.6163 - loss: -0.7337
# Epoch 21: val_loss improved from -0.82637 to -0.83711, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9949 - dice_coef: 0.7346 - iou_coef: 0.6173 - loss: -0.7346 - val_accuracy: 0.9965 - val_dice_coef: 0.8370 - val_iou_coef: 0.7228 - val_loss: -0.8371
# Epoch 22/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9971 - dice_coef: 0.8417 - iou_coef: 0.7298 - loss: -0.8417
# Epoch 22: val_loss did not improve from -0.83711
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 155ms/step - accuracy: 0.9971 - dice_coef: 0.8417 - iou_coef: 0.7298 - loss: -0.8417 - val_accuracy: 0.9965 - val_dice_coef: 0.8351 - val_iou_coef: 0.7190 - val_loss: -0.8351
# Epoch 23/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9946 - dice_coef: 0.7181 - iou_coef: 0.5989 - loss: -0.7181
# Epoch 23: val_loss did not improve from -0.83711
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.9947 - dice_coef: 0.7187 - iou_coef: 0.5994 - loss: -0.7187 - val_accuracy: 0.9960 - val_dice_coef: 0.8186 - val_iou_coef: 0.6964 - val_loss: -0.8179
# Epoch 24/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9958 - dice_coef: 0.7902 - iou_coef: 0.6763 - loss: -0.7902
# Epoch 24: val_loss did not improve from -0.83711
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 32s 411ms/step - accuracy: 0.9958 - dice_coef: 0.7904 - iou_coef: 0.6765 - loss: -0.7904 - val_accuracy: 0.9965 - val_dice_coef: 0.8354 - val_iou_coef: 0.7209 - val_loss: -0.8371
# Epoch 25/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9940 - dice_coef: 0.7311 - iou_coef: 0.6166 - loss: -0.7311
# Epoch 25: val_loss did not improve from -0.83711
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9941 - dice_coef: 0.7322 - iou_coef: 0.6177 - loss: -0.7321 - val_accuracy: 0.9965 - val_dice_coef: 0.8357 - val_iou_coef: 0.7205 - val_loss: -0.8366
# Epoch 26/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9971 - dice_coef: 0.8407 - iou_coef: 0.7295 - loss: -0.8407
# Epoch 26: val_loss improved from -0.83711 to -0.84376, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 262ms/step - accuracy: 0.9971 - dice_coef: 0.8408 - iou_coef: 0.7296 - loss: -0.8408 - val_accuracy: 0.9967 - val_dice_coef: 0.8435 - val_iou_coef: 0.7318 - val_loss: -0.8438
# Epoch 27/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9953 - dice_coef: 0.7649 - iou_coef: 0.6522 - loss: -0.7648
# Epoch 27: val_loss improved from -0.84376 to -0.85569, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 25s 318ms/step - accuracy: 0.9953 - dice_coef: 0.7652 - iou_coef: 0.6526 - loss: -0.7652 - val_accuracy: 0.9967 - val_dice_coef: 0.8558 - val_iou_coef: 0.7503 - val_loss: -0.8557
# Epoch 28/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9948 - dice_coef: 0.7282 - iou_coef: 0.6201 - loss: -0.7282
# Epoch 28: val_loss did not improve from -0.85569
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 526ms/step - accuracy: 0.9949 - dice_coef: 0.7294 - iou_coef: 0.6213 - loss: -0.7293 - val_accuracy: 0.9967 - val_dice_coef: 0.8519 - val_iou_coef: 0.7446 - val_loss: -0.8519
# Epoch 29/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9945 - dice_coef: 0.7239 - iou_coef: 0.6150 - loss: -0.7239
# Epoch 29: val_loss did not improve from -0.85569
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 531ms/step - accuracy: 0.9945 - dice_coef: 0.7251 - iou_coef: 0.6162 - loss: -0.7251 - val_accuracy: 0.9967 - val_dice_coef: 0.8502 - val_iou_coef: 0.7420 - val_loss: -0.8498
# Epoch 30/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9953 - dice_coef: 0.7266 - iou_coef: 0.6128 - loss: -0.7266
# Epoch 30: val_loss did not improve from -0.85569
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9953 - dice_coef: 0.7278 - iou_coef: 0.6141 - loss: -0.7278 - val_accuracy: 0.9969 - val_dice_coef: 0.8507 - val_iou_coef: 0.7422 - val_loss: -0.8504
# Epoch 31/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9971 - dice_coef: 0.8580 - iou_coef: 0.7545 - loss: -0.8580
# Epoch 31: val_loss did not improve from -0.85569
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 251ms/step - accuracy: 0.9971 - dice_coef: 0.8580 - iou_coef: 0.7545 - loss: -0.8580 - val_accuracy: 0.9967 - val_dice_coef: 0.8462 - val_iou_coef: 0.7372 - val_loss: -0.8463
# Epoch 32/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9957 - dice_coef: 0.7622 - iou_coef: 0.6572 - loss: -0.7622
# Epoch 32: val_loss did not improve from -0.85569
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 527ms/step - accuracy: 0.9957 - dice_coef: 0.7626 - iou_coef: 0.6576 - loss: -0.7626 - val_accuracy: 0.9964 - val_dice_coef: 0.8446 - val_iou_coef: 0.7343 - val_loss: -0.8444
# Epoch 33/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9968 - dice_coef: 0.8414 - iou_coef: 0.7381 - loss: -0.8414
# Epoch 33: val_loss improved from -0.85569 to -0.85780, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 0.9968 - dice_coef: 0.8413 - iou_coef: 0.7379 - loss: -0.8412 - val_accuracy: 0.9968 - val_dice_coef: 0.8574 - val_iou_coef: 0.7536 - val_loss: -0.8578
# Epoch 34/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9950 - dice_coef: 0.7459 - iou_coef: 0.6339 - loss: -0.7459
# Epoch 34: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 523ms/step - accuracy: 0.9950 - dice_coef: 0.7470 - iou_coef: 0.6351 - loss: -0.7470 - val_accuracy: 0.9966 - val_dice_coef: 0.8470 - val_iou_coef: 0.7369 - val_loss: -0.8467
# Epoch 35/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9950 - dice_coef: 0.7462 - iou_coef: 0.6422 - loss: -0.7462
# Epoch 35: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9950 - dice_coef: 0.7473 - iou_coef: 0.6433 - loss: -0.7473 - val_accuracy: 0.9968 - val_dice_coef: 0.8353 - val_iou_coef: 0.7230 - val_loss: -0.8342
# Epoch 36/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9974 - dice_coef: 0.8675 - iou_coef: 0.7686 - loss: -0.8675
# Epoch 36: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - accuracy: 0.9974 - dice_coef: 0.8676 - iou_coef: 0.7686 - loss: -0.8676 - val_accuracy: 0.9964 - val_dice_coef: 0.8402 - val_iou_coef: 0.7273 - val_loss: -0.8406
# Epoch 37/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9952 - dice_coef: 0.7532 - iou_coef: 0.6467 - loss: -0.7531
# Epoch 37: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 292ms/step - accuracy: 0.9952 - dice_coef: 0.7537 - iou_coef: 0.6472 - loss: -0.7536 - val_accuracy: 0.9965 - val_dice_coef: 0.8347 - val_iou_coef: 0.7202 - val_loss: -0.8338
# Epoch 38/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9948 - dice_coef: 0.7417 - iou_coef: 0.6334 - loss: -0.7417
# Epoch 38: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9948 - dice_coef: 0.7428 - iou_coef: 0.6346 - loss: -0.7428 - val_accuracy: 0.9968 - val_dice_coef: 0.8551 - val_iou_coef: 0.7495 - val_loss: -0.8543
# Epoch 39/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9975 - dice_coef: 0.8751 - iou_coef: 0.7804 - loss: -0.8751
# Epoch 39: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9975 - dice_coef: 0.8750 - iou_coef: 0.7803 - loss: -0.8750 - val_accuracy: 0.9970 - val_dice_coef: 0.8561 - val_iou_coef: 0.7512 - val_loss: -0.8560
# Epoch 40/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9951 - dice_coef: 0.7675 - iou_coef: 0.6556 - loss: -0.7675
# Epoch 40: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.9951 - dice_coef: 0.7680 - iou_coef: 0.6562 - loss: -0.7680 - val_accuracy: 0.9967 - val_dice_coef: 0.8341 - val_iou_coef: 0.7206 - val_loss: -0.8335
# Epoch 41/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9969 - dice_coef: 0.8302 - iou_coef: 0.7314 - loss: -0.8302
# Epoch 41: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 32s 409ms/step - accuracy: 0.9969 - dice_coef: 0.8304 - iou_coef: 0.7315 - loss: -0.8304 - val_accuracy: 0.9961 - val_dice_coef: 0.8369 - val_iou_coef: 0.7235 - val_loss: -0.8370
# Epoch 42/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9956 - dice_coef: 0.7593 - iou_coef: 0.6516 - loss: -0.7593
# Epoch 42: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 537ms/step - accuracy: 0.9956 - dice_coef: 0.7603 - iou_coef: 0.6527 - loss: -0.7603 - val_accuracy: 0.9963 - val_dice_coef: 0.8380 - val_iou_coef: 0.7247 - val_loss: -0.8378
# Epoch 43/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9945 - dice_coef: 0.7629 - iou_coef: 0.6513 - loss: -0.7629
# Epoch 43: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 534ms/step - accuracy: 0.9945 - dice_coef: 0.7638 - iou_coef: 0.6523 - loss: -0.7638 - val_accuracy: 0.9963 - val_dice_coef: 0.8338 - val_iou_coef: 0.7194 - val_loss: -0.8338
# Epoch 44/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9952 - dice_coef: 0.7495 - iou_coef: 0.6444 - loss: -0.7495
# Epoch 44: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9952 - dice_coef: 0.7506 - iou_coef: 0.6456 - loss: -0.7506 - val_accuracy: 0.9969 - val_dice_coef: 0.8576 - val_iou_coef: 0.7531 - val_loss: -0.8578
# Epoch 45/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9974 - dice_coef: 0.8690 - iou_coef: 0.7718 - loss: -0.8690
# Epoch 45: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 0.9974 - dice_coef: 0.8690 - iou_coef: 0.7718 - loss: -0.8690 - val_accuracy: 0.9964 - val_dice_coef: 0.8500 - val_iou_coef: 0.7415 - val_loss: -0.8495
# Epoch 46/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9950 - dice_coef: 0.7749 - iou_coef: 0.6661 - loss: -0.7749
# Epoch 46: val_loss did not improve from -0.85780
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 297ms/step - accuracy: 0.9950 - dice_coef: 0.7752 - iou_coef: 0.6664 - loss: -0.7752 - val_accuracy: 0.9970 - val_dice_coef: 0.8561 - val_iou_coef: 0.7532 - val_loss: -0.8559
# Epoch 47/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9956 - dice_coef: 0.7533 - iou_coef: 0.6524 - loss: -0.7533
# Epoch 47: val_loss improved from -0.85780 to -0.86604, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.9956 - dice_coef: 0.7545 - iou_coef: 0.6536 - loss: -0.7545 - val_accuracy: 0.9971 - val_dice_coef: 0.8666 - val_iou_coef: 0.7672 - val_loss: -0.8660
# Epoch 48/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9954 - dice_coef: 0.7372 - iou_coef: 0.6408 - loss: -0.7372
# Epoch 48: val_loss improved from -0.86604 to -0.86850, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9954 - dice_coef: 0.7385 - iou_coef: 0.6422 - loss: -0.7385 - val_accuracy: 0.9968 - val_dice_coef: 0.8691 - val_iou_coef: 0.7704 - val_loss: -0.8685
# Epoch 49/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9976 - dice_coef: 0.8820 - iou_coef: 0.7916 - loss: -0.8820
# Epoch 49: val_loss did not improve from -0.86850
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - accuracy: 0.9976 - dice_coef: 0.8820 - iou_coef: 0.7915 - loss: -0.8820 - val_accuracy: 0.9971 - val_dice_coef: 0.8655 - val_iou_coef: 0.7650 - val_loss: -0.8655
# Epoch 50/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9952 - dice_coef: 0.7640 - iou_coef: 0.6627 - loss: -0.7640
# Epoch 50: val_loss improved from -0.86850 to -0.87451, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 529ms/step - accuracy: 0.9952 - dice_coef: 0.7645 - iou_coef: 0.6632 - loss: -0.7645 - val_accuracy: 0.9972 - val_dice_coef: 0.8743 - val_iou_coef: 0.7787 - val_loss: -0.8745
# Epoch 51/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9970 - dice_coef: 0.8505 - iou_coef: 0.7585 - loss: -0.8505
# Epoch 51: val_loss improved from -0.87451 to -0.87705, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 25s 323ms/step - accuracy: 0.9970 - dice_coef: 0.8504 - iou_coef: 0.7583 - loss: -0.8504 - val_accuracy: 0.9972 - val_dice_coef: 0.8766 - val_iou_coef: 0.7823 - val_loss: -0.8770
# Epoch 52/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9945 - dice_coef: 0.7624 - iou_coef: 0.6578 - loss: -0.7624
# Epoch 52: val_loss did not improve from -0.87705
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.9946 - dice_coef: 0.7635 - iou_coef: 0.6590 - loss: -0.7635 - val_accuracy: 0.9972 - val_dice_coef: 0.8757 - val_iou_coef: 0.7807 - val_loss: -0.8752
# Epoch 53/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9954 - dice_coef: 0.7748 - iou_coef: 0.6714 - loss: -0.7748
# Epoch 53: val_loss improved from -0.87705 to -0.87827, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9954 - dice_coef: 0.7758 - iou_coef: 0.6725 - loss: -0.7758 - val_accuracy: 0.9973 - val_dice_coef: 0.8788 - val_iou_coef: 0.7856 - val_loss: -0.8783
# Epoch 54/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9976 - dice_coef: 0.8812 - iou_coef: 0.7902 - loss: -0.8812
# Epoch 54: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9976 - dice_coef: 0.8812 - iou_coef: 0.7902 - loss: -0.8812 - val_accuracy: 0.9971 - val_dice_coef: 0.8640 - val_iou_coef: 0.7631 - val_loss: -0.8643
# Epoch 55/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9951 - dice_coef: 0.7645 - iou_coef: 0.6621 - loss: -0.7645
# Epoch 55: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.9951 - dice_coef: 0.7650 - iou_coef: 0.6627 - loss: -0.7650 - val_accuracy: 0.9969 - val_dice_coef: 0.8709 - val_iou_coef: 0.7737 - val_loss: -0.8713
# Epoch 56/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9968 - dice_coef: 0.8400 - iou_coef: 0.7489 - loss: -0.8400
# Epoch 56: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 536ms/step - accuracy: 0.9968 - dice_coef: 0.8400 - iou_coef: 0.7489 - loss: -0.8400 - val_accuracy: 0.9970 - val_dice_coef: 0.8728 - val_iou_coef: 0.7765 - val_loss: -0.8734
# Epoch 57/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9968 - dice_coef: 0.8467 - iou_coef: 0.7482 - loss: -0.8467
# Epoch 57: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 425ms/step - accuracy: 0.9968 - dice_coef: 0.8468 - iou_coef: 0.7483 - loss: -0.8467 - val_accuracy: 0.9968 - val_dice_coef: 0.8561 - val_iou_coef: 0.7508 - val_loss: -0.8565
# Epoch 58/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.9954 - dice_coef: 0.7791 - iou_coef: 0.6745 - loss: -0.7791
# Epoch 58: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 43s 545ms/step - accuracy: 0.9955 - dice_coef: 0.7801 - iou_coef: 0.6756 - loss: -0.7800 - val_accuracy: 0.9970 - val_dice_coef: 0.8594 - val_iou_coef: 0.7559 - val_loss: -0.8593
# Epoch 59/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9953 - dice_coef: 0.7720 - iou_coef: 0.6701 - loss: -0.7720
# Epoch 59: val_loss did not improve from -0.87827
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9953 - dice_coef: 0.7731 - iou_coef: 0.6713 - loss: -0.7731 - val_accuracy: 0.9973 - val_dice_coef: 0.8734 - val_iou_coef: 0.7779 - val_loss: -0.8741
# Epoch 60/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9977 - dice_coef: 0.8882 - iou_coef: 0.8011 - loss: -0.8882
# Epoch 60: val_loss improved from -0.87827 to -0.87922, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 260ms/step - accuracy: 0.9977 - dice_coef: 0.8881 - iou_coef: 0.8010 - loss: -0.8881 - val_accuracy: 0.9972 - val_dice_coef: 0.8789 - val_iou_coef: 0.7858 - val_loss: -0.8792
# Epoch 61/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9955 - dice_coef: 0.7741 - iou_coef: 0.6770 - loss: -0.7741
# Epoch 61: val_loss did not improve from -0.87922
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 298ms/step - accuracy: 0.9955 - dice_coef: 0.7746 - iou_coef: 0.6775 - loss: -0.7746 - val_accuracy: 0.9971 - val_dice_coef: 0.8729 - val_iou_coef: 0.7765 - val_loss: -0.8732
# Epoch 62/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9955 - dice_coef: 0.7403 - iou_coef: 0.6483 - loss: -0.7403
# Epoch 62: val_loss did not improve from -0.87922
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 529ms/step - accuracy: 0.9956 - dice_coef: 0.7416 - iou_coef: 0.6497 - loss: -0.7416 - val_accuracy: 0.9971 - val_dice_coef: 0.8708 - val_iou_coef: 0.7733 - val_loss: -0.8713
# Epoch 63/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9957 - dice_coef: 0.7713 - iou_coef: 0.6734 - loss: -0.7713
# Epoch 63: val_loss did not improve from -0.87922
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 536ms/step - accuracy: 0.9957 - dice_coef: 0.7724 - iou_coef: 0.6746 - loss: -0.7724 - val_accuracy: 0.9972 - val_dice_coef: 0.8759 - val_iou_coef: 0.7812 - val_loss: -0.8765
# Epoch 64/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9951 - dice_coef: 0.7757 - iou_coef: 0.6731 - loss: -0.7757
# Epoch 64: val_loss improved from -0.87922 to -0.88057, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9951 - dice_coef: 0.7767 - iou_coef: 0.6743 - loss: -0.7767 - val_accuracy: 0.9973 - val_dice_coef: 0.8805 - val_iou_coef: 0.7883 - val_loss: -0.8806
# Epoch 65/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9978 - dice_coef: 0.8911 - iou_coef: 0.8063 - loss: -0.8911
# Epoch 65: val_loss did not improve from -0.88057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9978 - dice_coef: 0.8909 - iou_coef: 0.8061 - loss: -0.8909 - val_accuracy: 0.9972 - val_dice_coef: 0.8804 - val_iou_coef: 0.7881 - val_loss: -0.8804
# Epoch 66/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9952 - dice_coef: 0.7499 - iou_coef: 0.6475 - loss: -0.7499
# Epoch 66: val_loss did not improve from -0.88057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 513ms/step - accuracy: 0.9952 - dice_coef: 0.7509 - iou_coef: 0.6487 - loss: -0.7509 - val_accuracy: 0.9973 - val_dice_coef: 0.8786 - val_iou_coef: 0.7856 - val_loss: -0.8782
# Epoch 67/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9967 - dice_coef: 0.8363 - iou_coef: 0.7470 - loss: -0.8363
# Epoch 67: val_loss did not improve from -0.88057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 515ms/step - accuracy: 0.9967 - dice_coef: 0.8367 - iou_coef: 0.7474 - loss: -0.8367 - val_accuracy: 0.9973 - val_dice_coef: 0.8780 - val_iou_coef: 0.7844 - val_loss: -0.8780
# Epoch 68/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9966 - dice_coef: 0.8091 - iou_coef: 0.7133 - loss: -0.8091
# Epoch 68: val_loss did not improve from -0.88057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 525ms/step - accuracy: 0.9966 - dice_coef: 0.8096 - iou_coef: 0.7139 - loss: -0.8096 - val_accuracy: 0.9973 - val_dice_coef: 0.8730 - val_iou_coef: 0.7765 - val_loss: -0.8731
# Epoch 69/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9957 - dice_coef: 0.7987 - iou_coef: 0.7045 - loss: -0.7987
# Epoch 69: val_loss improved from -0.88057 to -0.88102, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 531ms/step - accuracy: 0.9957 - dice_coef: 0.7994 - iou_coef: 0.7053 - loss: -0.7994 - val_accuracy: 0.9973 - val_dice_coef: 0.8806 - val_iou_coef: 0.7888 - val_loss: -0.8810
# Epoch 70/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9958 - dice_coef: 0.7874 - iou_coef: 0.6843 - loss: -0.7874
# Epoch 70: val_loss did not improve from -0.88102
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9959 - dice_coef: 0.7882 - iou_coef: 0.6854 - loss: -0.7882 - val_accuracy: 0.9973 - val_dice_coef: 0.8798 - val_iou_coef: 0.7873 - val_loss: -0.8794
# Epoch 71/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9978 - dice_coef: 0.8903 - iou_coef: 0.8044 - loss: -0.8903
# Epoch 71: val_loss did not improve from -0.88102
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 260ms/step - accuracy: 0.9978 - dice_coef: 0.8903 - iou_coef: 0.8044 - loss: -0.8903 - val_accuracy: 0.9973 - val_dice_coef: 0.8728 - val_iou_coef: 0.7771 - val_loss: -0.8730
# Epoch 72/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9951 - dice_coef: 0.7690 - iou_coef: 0.6674 - loss: -0.7689
# Epoch 72: val_loss improved from -0.88102 to -0.88584, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 536ms/step - accuracy: 0.9951 - dice_coef: 0.7696 - iou_coef: 0.6682 - loss: -0.7696 - val_accuracy: 0.9972 - val_dice_coef: 0.8865 - val_iou_coef: 0.7980 - val_loss: -0.8858
# Epoch 73/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9972 - dice_coef: 0.8597 - iou_coef: 0.7730 - loss: -0.8597
# Epoch 73: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 510ms/step - accuracy: 0.9972 - dice_coef: 0.8596 - iou_coef: 0.7728 - loss: -0.8596 - val_accuracy: 0.9973 - val_dice_coef: 0.8791 - val_iou_coef: 0.7862 - val_loss: -0.8790
# Epoch 74/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9972 - dice_coef: 0.8620 - iou_coef: 0.7734 - loss: -0.8620
# Epoch 74: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 521ms/step - accuracy: 0.9972 - dice_coef: 0.8620 - iou_coef: 0.7734 - loss: -0.8620 - val_accuracy: 0.9974 - val_dice_coef: 0.8800 - val_iou_coef: 0.7880 - val_loss: -0.8801
# Epoch 75/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9971 - dice_coef: 0.8630 - iou_coef: 0.7770 - loss: -0.8630
# Epoch 75: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.9971 - dice_coef: 0.8629 - iou_coef: 0.7769 - loss: -0.8629 - val_accuracy: 0.9971 - val_dice_coef: 0.8660 - val_iou_coef: 0.7656 - val_loss: -0.8664
# Epoch 76/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9973 - dice_coef: 0.8651 - iou_coef: 0.7776 - loss: -0.8651
# Epoch 76: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 31s 392ms/step - accuracy: 0.9973 - dice_coef: 0.8650 - iou_coef: 0.7775 - loss: -0.8650 - val_accuracy: 0.9974 - val_dice_coef: 0.8770 - val_iou_coef: 0.7841 - val_loss: -0.8765
# Epoch 77/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9958 - dice_coef: 0.7816 - iou_coef: 0.6825 - loss: -0.7816
# Epoch 77: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9958 - dice_coef: 0.7826 - iou_coef: 0.6836 - loss: -0.7826 - val_accuracy: 0.9974 - val_dice_coef: 0.8806 - val_iou_coef: 0.7895 - val_loss: -0.8813
# Epoch 78/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9979 - dice_coef: 0.8925 - iou_coef: 0.8083 - loss: -0.8925
# Epoch 78: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 263ms/step - accuracy: 0.9979 - dice_coef: 0.8925 - iou_coef: 0.8083 - loss: -0.8925 - val_accuracy: 0.9975 - val_dice_coef: 0.8801 - val_iou_coef: 0.7877 - val_loss: -0.8799
# Epoch 79/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9950 - dice_coef: 0.7595 - iou_coef: 0.6667 - loss: -0.7594
# Epoch 79: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 527ms/step - accuracy: 0.9951 - dice_coef: 0.7602 - iou_coef: 0.6674 - loss: -0.7601 - val_accuracy: 0.9973 - val_dice_coef: 0.8669 - val_iou_coef: 0.7692 - val_loss: -0.8676
# Epoch 80/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9974 - dice_coef: 0.8639 - iou_coef: 0.7751 - loss: -0.8639
# Epoch 80: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 523ms/step - accuracy: 0.9974 - dice_coef: 0.8638 - iou_coef: 0.7750 - loss: -0.8638 - val_accuracy: 0.9972 - val_dice_coef: 0.8790 - val_iou_coef: 0.7859 - val_loss: -0.8791
# Epoch 81/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9972 - dice_coef: 0.8611 - iou_coef: 0.7716 - loss: -0.8611
# Epoch 81: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 27s 346ms/step - accuracy: 0.9972 - dice_coef: 0.8611 - iou_coef: 0.7716 - loss: -0.8611 - val_accuracy: 0.9974 - val_dice_coef: 0.8822 - val_iou_coef: 0.7914 - val_loss: -0.8829
# Epoch 82/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9950 - dice_coef: 0.7769 - iou_coef: 0.6791 - loss: -0.7769
# Epoch 82: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9950 - dice_coef: 0.7780 - iou_coef: 0.6804 - loss: -0.7780 - val_accuracy: 0.9974 - val_dice_coef: 0.8622 - val_iou_coef: 0.7622 - val_loss: -0.8620
# Epoch 83/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9979 - dice_coef: 0.8988 - iou_coef: 0.8185 - loss: -0.8988
# Epoch 83: val_loss did not improve from -0.88584
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 22s 275ms/step - accuracy: 0.9979 - dice_coef: 0.8987 - iou_coef: 0.8184 - loss: -0.8987 - val_accuracy: 0.9974 - val_dice_coef: 0.8795 - val_iou_coef: 0.7869 - val_loss: -0.8793
# Epoch 84/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9949 - dice_coef: 0.7729 - iou_coef: 0.6778 - loss: -0.7729
# Epoch 84: val_loss improved from -0.88584 to -0.89174, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 532ms/step - accuracy: 0.9950 - dice_coef: 0.7734 - iou_coef: 0.6784 - loss: -0.7734 - val_accuracy: 0.9975 - val_dice_coef: 0.8914 - val_iou_coef: 0.8057 - val_loss: -0.8917
# Epoch 85/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9972 - dice_coef: 0.8544 - iou_coef: 0.7630 - loss: -0.8544
# Epoch 85: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 25s 315ms/step - accuracy: 0.9972 - dice_coef: 0.8544 - iou_coef: 0.7631 - loss: -0.8544 - val_accuracy: 0.9975 - val_dice_coef: 0.8883 - val_iou_coef: 0.8008 - val_loss: -0.8876
# Epoch 86/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9960 - dice_coef: 0.7821 - iou_coef: 0.6870 - loss: -0.7821
# Epoch 86: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9961 - dice_coef: 0.7832 - iou_coef: 0.6882 - loss: -0.7832 - val_accuracy: 0.9975 - val_dice_coef: 0.8865 - val_iou_coef: 0.7978 - val_loss: -0.8868
# Epoch 87/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9981 - dice_coef: 0.8991 - iou_coef: 0.8191 - loss: -0.8991
# Epoch 87: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9981 - dice_coef: 0.8991 - iou_coef: 0.8190 - loss: -0.8991 - val_accuracy: 0.9974 - val_dice_coef: 0.8812 - val_iou_coef: 0.7904 - val_loss: -0.8824
# Epoch 88/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9950 - dice_coef: 0.7608 - iou_coef: 0.6622 - loss: -0.7608
# Epoch 88: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 517ms/step - accuracy: 0.9951 - dice_coef: 0.7616 - iou_coef: 0.6631 - loss: -0.7616 - val_accuracy: 0.9974 - val_dice_coef: 0.8840 - val_iou_coef: 0.7945 - val_loss: -0.8840
# Epoch 89/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9969 - dice_coef: 0.8414 - iou_coef: 0.7510 - loss: -0.8414
# Epoch 89: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 34s 439ms/step - accuracy: 0.9969 - dice_coef: 0.8416 - iou_coef: 0.7513 - loss: -0.8416 - val_accuracy: 0.9973 - val_dice_coef: 0.8753 - val_iou_coef: 0.7807 - val_loss: -0.8754
# Epoch 90/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9963 - dice_coef: 0.7825 - iou_coef: 0.6856 - loss: -0.7825
# Epoch 90: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.9963 - dice_coef: 0.7836 - iou_coef: 0.6868 - loss: -0.7836 - val_accuracy: 0.9974 - val_dice_coef: 0.8889 - val_iou_coef: 0.8016 - val_loss: -0.8891
# Epoch 91/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9965 - dice_coef: 0.7957 - iou_coef: 0.6999 - loss: -0.7957
# Epoch 91: val_loss did not improve from -0.89174
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9965 - dice_coef: 0.7966 - iou_coef: 0.7010 - loss: -0.7966 - val_accuracy: 0.9975 - val_dice_coef: 0.8848 - val_iou_coef: 0.7958 - val_loss: -0.8854
# Epoch 92/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9979 - dice_coef: 0.8972 - iou_coef: 0.8156 - loss: -0.8972
# Epoch 92: val_loss improved from -0.89174 to -0.89740, saving model to /content/drive/MyDrive/unet_final_combination.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 23s 289ms/step - accuracy: 0.9979 - dice_coef: 0.8972 - iou_coef: 0.8156 - loss: -0.8972 - val_accuracy: 0.9978 - val_dice_coef: 0.8971 - val_iou_coef: 0.8151 - val_loss: -0.8974
# Epoch 93/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9960 - dice_coef: 0.8013 - iou_coef: 0.7055 - loss: -0.8013
# Epoch 93: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 506ms/step - accuracy: 0.9960 - dice_coef: 0.8017 - iou_coef: 0.7059 - loss: -0.8017 - val_accuracy: 0.9970 - val_dice_coef: 0.8712 - val_iou_coef: 0.7741 - val_loss: -0.8708
# Epoch 94/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9974 - dice_coef: 0.8735 - iou_coef: 0.7915 - loss: -0.8735
# Epoch 94: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.9974 - dice_coef: 0.8734 - iou_coef: 0.7913 - loss: -0.8734 - val_accuracy: 0.9975 - val_dice_coef: 0.8873 - val_iou_coef: 0.7997 - val_loss: -0.8872
# Epoch 95/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9973 - dice_coef: 0.8665 - iou_coef: 0.7830 - loss: -0.8665
# Epoch 95: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 27s 343ms/step - accuracy: 0.9973 - dice_coef: 0.8665 - iou_coef: 0.7829 - loss: -0.8665 - val_accuracy: 0.9976 - val_dice_coef: 0.8871 - val_iou_coef: 0.7996 - val_loss: -0.8868
# Epoch 96/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9956 - dice_coef: 0.7919 - iou_coef: 0.6942 - loss: -0.7919
# Epoch 96: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 541ms/step - accuracy: 0.9957 - dice_coef: 0.7929 - iou_coef: 0.6954 - loss: -0.7929 - val_accuracy: 0.9976 - val_dice_coef: 0.8818 - val_iou_coef: 0.7906 - val_loss: -0.8819
# Epoch 97/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9952 - dice_coef: 0.7508 - iou_coef: 0.6583 - loss: -0.7508
# Epoch 97: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.9952 - dice_coef: 0.7521 - iou_coef: 0.6598 - loss: -0.7521 - val_accuracy: 0.9974 - val_dice_coef: 0.8879 - val_iou_coef: 0.8001 - val_loss: -0.8879
# Epoch 98/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9943 - dice_coef: 0.7417 - iou_coef: 0.6465 - loss: -0.7417
# Epoch 98: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9943 - dice_coef: 0.7430 - iou_coef: 0.6479 - loss: -0.7430 - val_accuracy: 0.9971 - val_dice_coef: 0.8632 - val_iou_coef: 0.7626 - val_loss: -0.8629
# Epoch 99/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_coef: 0.8966 - iou_coef: 0.8150 - loss: -0.8966
# Epoch 99: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9980 - dice_coef: 0.8966 - iou_coef: 0.8151 - loss: -0.8966 - val_accuracy: 0.9974 - val_dice_coef: 0.8873 - val_iou_coef: 0.7998 - val_loss: -0.8871
# Epoch 100/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9950 - dice_coef: 0.7536 - iou_coef: 0.6577 - loss: -0.7536
# Epoch 100: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.9950 - dice_coef: 0.7544 - iou_coef: 0.6586 - loss: -0.7544 - val_accuracy: 0.9973 - val_dice_coef: 0.8806 - val_iou_coef: 0.7894 - val_loss: -0.8801
# Epoch 101/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9968 - dice_coef: 0.8456 - iou_coef: 0.7648 - loss: -0.8456
# Epoch 101: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 417ms/step - accuracy: 0.9968 - dice_coef: 0.8458 - iou_coef: 0.7649 - loss: -0.8458 - val_accuracy: 0.9972 - val_dice_coef: 0.8736 - val_iou_coef: 0.7774 - val_loss: -0.8732
# Epoch 102/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9953 - dice_coef: 0.7826 - iou_coef: 0.6892 - loss: -0.7825
# Epoch 102: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9953 - dice_coef: 0.7836 - iou_coef: 0.6905 - loss: -0.7836 - val_accuracy: 0.9975 - val_dice_coef: 0.8864 - val_iou_coef: 0.7982 - val_loss: -0.8871
# Epoch 103/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9981 - dice_coef: 0.8998 - iou_coef: 0.8199 - loss: -0.8998
# Epoch 103: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 167ms/step - accuracy: 0.9981 - dice_coef: 0.8998 - iou_coef: 0.8199 - loss: -0.8997 - val_accuracy: 0.9975 - val_dice_coef: 0.8867 - val_iou_coef: 0.7989 - val_loss: -0.8866
# Epoch 104/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9956 - dice_coef: 0.7889 - iou_coef: 0.6963 - loss: -0.7889
# Epoch 104: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 523ms/step - accuracy: 0.9956 - dice_coef: 0.7894 - iou_coef: 0.6969 - loss: -0.7894 - val_accuracy: 0.9975 - val_dice_coef: 0.8895 - val_iou_coef: 0.8026 - val_loss: -0.8899
# Epoch 105/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.9968 - dice_coef: 0.8512 - iou_coef: 0.7651 - loss: -0.8512
# Epoch 105: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 33s 416ms/step - accuracy: 0.9968 - dice_coef: 0.8513 - iou_coef: 0.7652 - loss: -0.8513 - val_accuracy: 0.9973 - val_dice_coef: 0.8820 - val_iou_coef: 0.7914 - val_loss: -0.8818
# Epoch 106/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9950 - dice_coef: 0.7565 - iou_coef: 0.6616 - loss: -0.7565
# Epoch 106: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9951 - dice_coef: 0.7579 - iou_coef: 0.6631 - loss: -0.7579 - val_accuracy: 0.9976 - val_dice_coef: 0.8867 - val_iou_coef: 0.7986 - val_loss: -0.8876
# Epoch 107/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9981 - dice_coef: 0.9018 - iou_coef: 0.8234 - loss: -0.9018
# Epoch 107: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9981 - dice_coef: 0.9018 - iou_coef: 0.8234 - loss: -0.9018 - val_accuracy: 0.9975 - val_dice_coef: 0.8849 - val_iou_coef: 0.7956 - val_loss: -0.8845
# Epoch 108/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9961 - dice_coef: 0.7841 - iou_coef: 0.6889 - loss: -0.7841
# Epoch 108: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 532ms/step - accuracy: 0.9961 - dice_coef: 0.7848 - iou_coef: 0.6897 - loss: -0.7848 - val_accuracy: 0.9974 - val_dice_coef: 0.8826 - val_iou_coef: 0.7916 - val_loss: -0.8830
# Epoch 109/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9969 - dice_coef: 0.8539 - iou_coef: 0.7693 - loss: -0.8539
# Epoch 109: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 528ms/step - accuracy: 0.9969 - dice_coef: 0.8540 - iou_coef: 0.7695 - loss: -0.8540 - val_accuracy: 0.9974 - val_dice_coef: 0.8849 - val_iou_coef: 0.7950 - val_loss: -0.8849
# Epoch 110/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9970 - dice_coef: 0.8454 - iou_coef: 0.7572 - loss: -0.8454
# Epoch 110: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.9970 - dice_coef: 0.8457 - iou_coef: 0.7575 - loss: -0.8457 - val_accuracy: 0.9975 - val_dice_coef: 0.8833 - val_iou_coef: 0.7934 - val_loss: -0.8836
# Epoch 111/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9965 - dice_coef: 0.8357 - iou_coef: 0.7555 - loss: -0.8357
# Epoch 111: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 516ms/step - accuracy: 0.9966 - dice_coef: 0.8360 - iou_coef: 0.7559 - loss: -0.8360 - val_accuracy: 0.9973 - val_dice_coef: 0.8871 - val_iou_coef: 0.7987 - val_loss: -0.8874
# Epoch 112/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9964 - dice_coef: 0.8299 - iou_coef: 0.7464 - loss: -0.8299
# Epoch 112: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 38s 486ms/step - accuracy: 0.9964 - dice_coef: 0.8304 - iou_coef: 0.7469 - loss: -0.8304 - val_accuracy: 0.9975 - val_dice_coef: 0.8901 - val_iou_coef: 0.8039 - val_loss: -0.8906
# Epoch 113/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9957 - dice_coef: 0.7873 - iou_coef: 0.6961 - loss: -0.7873
# Epoch 113: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9957 - dice_coef: 0.7884 - iou_coef: 0.6974 - loss: -0.7883 - val_accuracy: 0.9974 - val_dice_coef: 0.8914 - val_iou_coef: 0.8059 - val_loss: -0.8911
# Epoch 114/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9981 - dice_coef: 0.9049 - iou_coef: 0.8282 - loss: -0.9049
# Epoch 114: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9981 - dice_coef: 0.9049 - iou_coef: 0.8282 - loss: -0.9049 - val_accuracy: 0.9975 - val_dice_coef: 0.8888 - val_iou_coef: 0.8017 - val_loss: -0.8885
# Epoch 115/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9957 - dice_coef: 0.8016 - iou_coef: 0.7083 - loss: -0.8016
# Epoch 115: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 524ms/step - accuracy: 0.9957 - dice_coef: 0.8020 - iou_coef: 0.7088 - loss: -0.8020 - val_accuracy: 0.9978 - val_dice_coef: 0.8872 - val_iou_coef: 0.7996 - val_loss: -0.8866
# Epoch 116/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9974 - dice_coef: 0.8724 - iou_coef: 0.7920 - loss: -0.8724
# Epoch 116: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.9974 - dice_coef: 0.8723 - iou_coef: 0.7918 - loss: -0.8723 - val_accuracy: 0.9975 - val_dice_coef: 0.8924 - val_iou_coef: 0.8075 - val_loss: -0.8924
# Epoch 117/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9975 - dice_coef: 0.8756 - iou_coef: 0.7964 - loss: -0.8756
# Epoch 117: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 27s 341ms/step - accuracy: 0.9975 - dice_coef: 0.8755 - iou_coef: 0.7962 - loss: -0.8755 - val_accuracy: 0.9975 - val_dice_coef: 0.8903 - val_iou_coef: 0.8045 - val_loss: -0.8900
# Epoch 118/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9955 - dice_coef: 0.7652 - iou_coef: 0.6793 - loss: -0.7652
# Epoch 118: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9955 - dice_coef: 0.7664 - iou_coef: 0.6805 - loss: -0.7664 - val_accuracy: 0.9975 - val_dice_coef: 0.8805 - val_iou_coef: 0.7890 - val_loss: -0.8808
# Epoch 119/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9981 - dice_coef: 0.9065 - iou_coef: 0.8311 - loss: -0.9065
# Epoch 119: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - accuracy: 0.9981 - dice_coef: 0.9065 - iou_coef: 0.8311 - loss: -0.9065 - val_accuracy: 0.9977 - val_dice_coef: 0.8843 - val_iou_coef: 0.7947 - val_loss: -0.8842
# Epoch 120/120
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9958 - dice_coef: 0.7779 - iou_coef: 0.6809 - loss: -0.7779
# Epoch 120: val_loss did not improve from -0.89740
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 32s 403ms/step - accuracy: 0.9958 - dice_coef: 0.7786 - iou_coef: 0.6817 - loss: -0.7786 - val_accuracy: 0.9975 - val_dice_coef: 0.8853 - val_iou_coef: 0.7961 - val_loss: -0.8853

# %%
plot_training(history)

# %%
model.save('/content/drive/MyDrive/unet_final_combination.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/unet_final_combination.hdf5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)


print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print("Train IoU: ", train_score[2])
print("Train Dice: ", train_score[3])
print('-' * 20)

print("Valid Loss: ", valid_score[0])
print("Valid Accuracy: ", valid_score[1])
print("Valid IoU: ", valid_score[2])
print("Valid Dice: ", valid_score[3])
print('-' * 20)

print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
print("Test IoU: ", test_score[2])
print("Test Dice: ", test_score[3])
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 66s 507ms/step - accuracy: 0.9833 - dice_coef: 0.1641 - iou_coef: 0.1338 - loss: -0.1645
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 38s 294ms/step - accuracy: 0.9976 - dice_coef: 0.8891 - iou_coef: 0.8026 - loss: -0.8894
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 495s 4s/step - accuracy: 0.9979 - dice_coef: 0.8761 - iou_coef: 0.7838 - loss: -0.8758
# Train Loss:  -0.43786659836769104
# Train Accuracy:  0.9888579845428467
# Train IoU:  0.3889687955379486
# Train Dice:  0.43670567870140076
# --------------------
# Valid Loss:  -0.8908809423446655
# Valid Accuracy:  0.9976187944412231
# Valid IoU:  0.8050801753997803
# Valid Dice:  0.8906877040863037
# --------------------
# Test Loss:  -0.8797354698181152
# Test Accuracy:  0.9979107975959778
# Test IoU:  0.7889542579650879
# Test Dice:  0.8797797560691833

# %%
for _ in range(20):
    index = np.random.randint(1, len(test_df.index))
    img = cv2.imread(test_df['images_paths'].iloc[index])
    img = cv2.resize(img, (128, 128))
    img = img/255
    img = img[np.newaxis, :, :, : ]

    predicted_img = model.predict(img)

    plt.figure(figsize=(12, 12))

    plt.subplot(1, 3, 1)
    plt.imshow(np.squeeze(img))
    plt.axis('off')
    plt.title('Original Image')

    plt.subplot(1, 3, 2)
    plt.imshow(np.squeeze(cv2.imread(test_df['masks_paths'].iloc[index])))
    plt.axis('off')
    plt.title('Original Mask')

    plt.subplot(1, 3, 3)
    plt.imshow(np.squeeze(predicted_img) > 0.5 )
    plt.title('Prediction')
    plt.axis('off')

    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
